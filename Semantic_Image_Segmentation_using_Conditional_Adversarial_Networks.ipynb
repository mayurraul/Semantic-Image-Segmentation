# %% [markdown]
# <a href="https://colab.research.google.com/github/mayurraul/Semantic-Image-Segmentation/blob/master/Semantic_Image_Segmentation_using_Conditional_Adversarial_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
! pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e0314151-f73d-4058-9431-ad7007c32c34" name="files[]" multiple disabled />
#      <output id="result-e0314151-f73d-4058-9431-ad7007c32c34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"mayurraul67","key":"5895e91c7edf937f6ef991d8be88565a"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d dansbecker/cityscapes-image-pairs
# Out:
# Downloading cityscapes-image-pairs.zip to /content
#  96% 193M/202M [00:01<00:00, 106MB/s]
# 100% 202M/202M [00:01<00:00, 108MB/s]

# %%
! mkdir train
! unzip cityscapes-image-pairs.zip -d train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/cityscapes_data/cityscapes_data/train/2755.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2756.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2757.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2758.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2759.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/276.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2760.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2761.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2762.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2763.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2764.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2765.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2766.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2767.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2768.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2769.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/277.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2770.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2771.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2772.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2773.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2774.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2775.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2776.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2777.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2778.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2779.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/278.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2780.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2781.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2782.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2783.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2784.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2785.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2786.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2787.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2788.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2789.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/279.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2790.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2791.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2792.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2793.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2794.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2795.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2796.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2797.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2798.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2799.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/28.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/280.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2800.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2801.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2802.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2803.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2804.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2805.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2806.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2807.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2808.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2809.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/281.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2810.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2811.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2812.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2813.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2814.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2815.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2816.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2817.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2818.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2819.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/282.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2820.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2821.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2822.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2823.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2824.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2825.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2826.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2827.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2828.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2829.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/283.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2830.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2831.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2832.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2833.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2834.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2835.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2836.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2837.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2838.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2839.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/284.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2840.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2841.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2842.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2843.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2844.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2845.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2846.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2847.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2848.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2849.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/285.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2850.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2851.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2852.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2853.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2854.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2855.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2856.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2857.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2858.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2859.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/286.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2860.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2861.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2862.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2863.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2864.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2865.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2866.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2867.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2868.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2869.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/287.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2870.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2871.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2872.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2873.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2874.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2875.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2876.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2877.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2878.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2879.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/288.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2880.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2881.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2882.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2883.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2884.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2885.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2886.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2887.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2888.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2889.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/289.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2890.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2891.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2892.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2893.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2894.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2895.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2896.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2897.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2898.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2899.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/29.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/290.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2900.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2901.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2902.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2903.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2904.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2905.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2906.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2907.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2908.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2909.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/291.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2910.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2911.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2912.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2913.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2914.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2915.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2916.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2917.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2918.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2919.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/292.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2920.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2921.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2922.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2923.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2924.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2925.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2926.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2927.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2928.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2929.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/293.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2930.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2931.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2932.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2933.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2934.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2935.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2936.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2937.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2938.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2939.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/294.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2940.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2941.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2942.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2943.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2944.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2945.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2946.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2947.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2948.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2949.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/295.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2950.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2951.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2952.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2953.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2954.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2955.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2956.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2957.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2958.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2959.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/296.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2960.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2961.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2962.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2963.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2964.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2965.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2966.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2967.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2968.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2969.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/297.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2970.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2971.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2972.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2973.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2974.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/2975.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/298.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/299.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/3.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/30.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/300.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/301.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/302.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/303.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/304.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/305.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/306.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/307.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/308.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/309.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/31.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/310.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/311.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/312.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/313.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/314.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/315.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/316.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/317.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/318.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/319.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/32.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/320.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/321.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/322.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/323.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/324.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/325.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/326.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/327.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/328.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/329.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/33.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/330.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/331.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/332.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/333.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/334.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/335.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/336.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/337.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/338.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/339.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/34.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/340.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/341.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/342.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/343.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/344.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/345.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/346.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/347.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/348.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/349.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/35.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/350.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/351.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/352.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/353.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/354.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/355.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/356.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/357.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/358.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/359.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/36.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/360.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/361.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/362.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/363.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/364.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/365.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/366.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/367.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/368.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/369.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/37.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/370.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/371.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/372.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/373.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/374.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/375.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/376.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/377.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/378.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/379.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/38.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/380.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/381.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/382.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/383.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/384.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/385.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/386.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/387.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/388.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/389.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/39.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/390.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/391.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/392.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/393.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/394.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/395.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/396.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/397.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/398.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/399.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/4.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/40.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/400.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/401.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/402.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/403.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/404.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/405.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/406.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/407.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/408.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/409.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/41.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/410.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/411.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/412.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/413.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/414.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/415.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/416.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/417.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/418.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/419.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/42.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/420.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/421.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/422.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/423.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/424.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/425.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/426.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/427.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/428.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/429.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/43.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/430.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/431.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/432.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/433.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/434.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/435.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/436.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/437.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/438.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/439.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/44.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/440.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/441.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/442.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/443.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/444.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/445.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/446.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/447.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/448.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/449.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/45.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/450.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/451.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/452.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/453.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/454.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/455.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/456.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/457.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/458.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/459.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/46.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/460.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/461.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/462.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/463.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/464.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/465.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/466.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/467.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/468.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/469.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/47.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/470.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/471.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/472.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/473.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/474.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/475.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/476.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/477.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/478.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/479.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/48.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/480.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/481.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/482.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/483.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/484.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/485.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/486.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/487.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/488.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/489.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/49.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/490.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/491.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/492.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/493.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/494.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/495.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/496.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/497.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/498.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/499.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/5.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/50.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/500.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/501.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/502.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/503.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/504.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/505.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/506.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/507.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/508.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/509.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/51.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/510.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/511.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/512.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/513.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/514.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/515.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/516.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/517.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/518.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/519.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/52.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/520.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/521.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/522.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/523.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/524.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/525.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/526.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/527.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/528.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/529.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/53.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/530.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/531.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/532.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/533.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/534.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/535.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/536.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/537.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/538.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/539.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/54.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/540.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/541.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/542.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/543.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/544.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/545.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/546.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/547.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/548.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/549.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/55.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/550.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/551.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/552.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/553.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/554.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/555.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/556.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/557.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/558.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/559.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/56.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/560.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/561.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/562.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/563.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/564.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/565.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/566.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/567.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/568.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/569.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/57.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/570.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/571.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/572.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/573.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/574.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/575.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/576.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/577.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/578.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/579.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/58.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/580.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/581.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/582.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/583.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/584.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/585.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/586.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/587.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/588.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/589.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/59.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/590.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/591.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/592.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/593.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/594.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/595.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/596.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/597.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/598.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/599.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/6.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/60.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/600.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/601.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/602.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/603.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/604.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/605.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/606.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/607.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/608.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/609.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/61.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/610.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/611.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/612.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/613.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/614.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/615.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/616.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/617.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/618.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/619.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/62.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/620.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/621.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/622.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/623.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/624.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/625.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/626.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/627.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/628.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/629.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/63.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/630.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/631.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/632.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/633.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/634.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/635.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/636.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/637.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/638.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/639.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/64.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/640.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/641.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/642.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/643.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/644.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/645.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/646.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/647.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/648.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/649.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/65.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/650.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/651.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/652.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/653.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/654.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/655.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/656.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/657.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/658.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/659.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/66.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/660.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/661.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/662.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/663.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/664.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/665.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/666.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/667.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/668.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/669.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/67.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/670.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/671.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/672.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/673.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/674.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/675.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/676.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/677.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/678.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/679.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/68.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/680.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/681.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/682.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/683.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/684.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/685.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/686.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/687.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/688.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/689.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/69.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/690.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/691.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/692.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/693.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/694.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/695.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/696.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/697.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/698.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/699.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/7.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/70.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/700.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/701.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/702.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/703.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/704.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/705.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/706.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/707.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/708.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/709.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/71.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/710.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/711.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/712.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/713.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/714.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/715.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/716.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/717.jpg
#   inflating: train/cityscapes_data/cityscapes_data/train/718.jpg
# ...
#   inflating: train/cityscapes_data/val/254.jpg
#   inflating: train/cityscapes_data/val/255.jpg
#   inflating: train/cityscapes_data/val/256.jpg
#   inflating: train/cityscapes_data/val/257.jpg
#   inflating: train/cityscapes_data/val/258.jpg
#   inflating: train/cityscapes_data/val/259.jpg
#   inflating: train/cityscapes_data/val/26.jpg
#   inflating: train/cityscapes_data/val/260.jpg
#   inflating: train/cityscapes_data/val/261.jpg
#   inflating: train/cityscapes_data/val/262.jpg
#   inflating: train/cityscapes_data/val/263.jpg
#   inflating: train/cityscapes_data/val/264.jpg
#   inflating: train/cityscapes_data/val/265.jpg
#   inflating: train/cityscapes_data/val/266.jpg
#   inflating: train/cityscapes_data/val/267.jpg
#   inflating: train/cityscapes_data/val/268.jpg
#   inflating: train/cityscapes_data/val/269.jpg
#   inflating: train/cityscapes_data/val/27.jpg
#   inflating: train/cityscapes_data/val/270.jpg
#   inflating: train/cityscapes_data/val/271.jpg
#   inflating: train/cityscapes_data/val/272.jpg
#   inflating: train/cityscapes_data/val/273.jpg
#   inflating: train/cityscapes_data/val/274.jpg
#   inflating: train/cityscapes_data/val/275.jpg
#   inflating: train/cityscapes_data/val/276.jpg
#   inflating: train/cityscapes_data/val/277.jpg
#   inflating: train/cityscapes_data/val/278.jpg
#   inflating: train/cityscapes_data/val/279.jpg
#   inflating: train/cityscapes_data/val/28.jpg
#   inflating: train/cityscapes_data/val/280.jpg
#   inflating: train/cityscapes_data/val/281.jpg
#   inflating: train/cityscapes_data/val/282.jpg
#   inflating: train/cityscapes_data/val/283.jpg
#   inflating: train/cityscapes_data/val/284.jpg
#   inflating: train/cityscapes_data/val/285.jpg
#   inflating: train/cityscapes_data/val/286.jpg
#   inflating: train/cityscapes_data/val/287.jpg
#   inflating: train/cityscapes_data/val/288.jpg
#   inflating: train/cityscapes_data/val/289.jpg
#   inflating: train/cityscapes_data/val/29.jpg
#   inflating: train/cityscapes_data/val/290.jpg
#   inflating: train/cityscapes_data/val/291.jpg
#   inflating: train/cityscapes_data/val/292.jpg
#   inflating: train/cityscapes_data/val/293.jpg
#   inflating: train/cityscapes_data/val/294.jpg
#   inflating: train/cityscapes_data/val/295.jpg
#   inflating: train/cityscapes_data/val/296.jpg
#   inflating: train/cityscapes_data/val/297.jpg
#   inflating: train/cityscapes_data/val/298.jpg
#   inflating: train/cityscapes_data/val/299.jpg
#   inflating: train/cityscapes_data/val/3.jpg
#   inflating: train/cityscapes_data/val/30.jpg
#   inflating: train/cityscapes_data/val/300.jpg
#   inflating: train/cityscapes_data/val/301.jpg
#   inflating: train/cityscapes_data/val/302.jpg
#   inflating: train/cityscapes_data/val/303.jpg
#   inflating: train/cityscapes_data/val/304.jpg
#   inflating: train/cityscapes_data/val/305.jpg
#   inflating: train/cityscapes_data/val/306.jpg
#   inflating: train/cityscapes_data/val/307.jpg
#   inflating: train/cityscapes_data/val/308.jpg
#   inflating: train/cityscapes_data/val/309.jpg
#   inflating: train/cityscapes_data/val/31.jpg
#   inflating: train/cityscapes_data/val/310.jpg
#   inflating: train/cityscapes_data/val/311.jpg
#   inflating: train/cityscapes_data/val/312.jpg
#   inflating: train/cityscapes_data/val/313.jpg
#   inflating: train/cityscapes_data/val/314.jpg
#   inflating: train/cityscapes_data/val/315.jpg
#   inflating: train/cityscapes_data/val/316.jpg
#   inflating: train/cityscapes_data/val/317.jpg
#   inflating: train/cityscapes_data/val/318.jpg
#   inflating: train/cityscapes_data/val/319.jpg
#   inflating: train/cityscapes_data/val/32.jpg
#   inflating: train/cityscapes_data/val/320.jpg
#   inflating: train/cityscapes_data/val/321.jpg
#   inflating: train/cityscapes_data/val/322.jpg
#   inflating: train/cityscapes_data/val/323.jpg
#   inflating: train/cityscapes_data/val/324.jpg
#   inflating: train/cityscapes_data/val/325.jpg
#   inflating: train/cityscapes_data/val/326.jpg
#   inflating: train/cityscapes_data/val/327.jpg
#   inflating: train/cityscapes_data/val/328.jpg
#   inflating: train/cityscapes_data/val/329.jpg
#   inflating: train/cityscapes_data/val/33.jpg
#   inflating: train/cityscapes_data/val/330.jpg
#   inflating: train/cityscapes_data/val/331.jpg
#   inflating: train/cityscapes_data/val/332.jpg
#   inflating: train/cityscapes_data/val/333.jpg
#   inflating: train/cityscapes_data/val/334.jpg
#   inflating: train/cityscapes_data/val/335.jpg
#   inflating: train/cityscapes_data/val/336.jpg
#   inflating: train/cityscapes_data/val/337.jpg
#   inflating: train/cityscapes_data/val/338.jpg
#   inflating: train/cityscapes_data/val/339.jpg
#   inflating: train/cityscapes_data/val/34.jpg
#   inflating: train/cityscapes_data/val/340.jpg
#   inflating: train/cityscapes_data/val/341.jpg
#   inflating: train/cityscapes_data/val/342.jpg
#   inflating: train/cityscapes_data/val/343.jpg
#   inflating: train/cityscapes_data/val/344.jpg
#   inflating: train/cityscapes_data/val/345.jpg
#   inflating: train/cityscapes_data/val/346.jpg
#   inflating: train/cityscapes_data/val/347.jpg
#   inflating: train/cityscapes_data/val/348.jpg
#   inflating: train/cityscapes_data/val/349.jpg
#   inflating: train/cityscapes_data/val/35.jpg
#   inflating: train/cityscapes_data/val/350.jpg
#   inflating: train/cityscapes_data/val/351.jpg
#   inflating: train/cityscapes_data/val/352.jpg
#   inflating: train/cityscapes_data/val/353.jpg
#   inflating: train/cityscapes_data/val/354.jpg
#   inflating: train/cityscapes_data/val/355.jpg
#   inflating: train/cityscapes_data/val/356.jpg
#   inflating: train/cityscapes_data/val/357.jpg
#   inflating: train/cityscapes_data/val/358.jpg
#   inflating: train/cityscapes_data/val/359.jpg
#   inflating: train/cityscapes_data/val/36.jpg
#   inflating: train/cityscapes_data/val/360.jpg
#   inflating: train/cityscapes_data/val/361.jpg
#   inflating: train/cityscapes_data/val/362.jpg
#   inflating: train/cityscapes_data/val/363.jpg
#   inflating: train/cityscapes_data/val/364.jpg
#   inflating: train/cityscapes_data/val/365.jpg
#   inflating: train/cityscapes_data/val/366.jpg
#   inflating: train/cityscapes_data/val/367.jpg
#   inflating: train/cityscapes_data/val/368.jpg
#   inflating: train/cityscapes_data/val/369.jpg
#   inflating: train/cityscapes_data/val/37.jpg
#   inflating: train/cityscapes_data/val/370.jpg
#   inflating: train/cityscapes_data/val/371.jpg
#   inflating: train/cityscapes_data/val/372.jpg
#   inflating: train/cityscapes_data/val/373.jpg
#   inflating: train/cityscapes_data/val/374.jpg
#   inflating: train/cityscapes_data/val/375.jpg
#   inflating: train/cityscapes_data/val/376.jpg
#   inflating: train/cityscapes_data/val/377.jpg
#   inflating: train/cityscapes_data/val/378.jpg
#   inflating: train/cityscapes_data/val/379.jpg
#   inflating: train/cityscapes_data/val/38.jpg
#   inflating: train/cityscapes_data/val/380.jpg
#   inflating: train/cityscapes_data/val/381.jpg
#   inflating: train/cityscapes_data/val/382.jpg
#   inflating: train/cityscapes_data/val/383.jpg
#   inflating: train/cityscapes_data/val/384.jpg
#   inflating: train/cityscapes_data/val/385.jpg
#   inflating: train/cityscapes_data/val/386.jpg
#   inflating: train/cityscapes_data/val/387.jpg
#   inflating: train/cityscapes_data/val/388.jpg
#   inflating: train/cityscapes_data/val/389.jpg
#   inflating: train/cityscapes_data/val/39.jpg
#   inflating: train/cityscapes_data/val/390.jpg
#   inflating: train/cityscapes_data/val/391.jpg
#   inflating: train/cityscapes_data/val/392.jpg
#   inflating: train/cityscapes_data/val/393.jpg
#   inflating: train/cityscapes_data/val/394.jpg
#   inflating: train/cityscapes_data/val/395.jpg
#   inflating: train/cityscapes_data/val/396.jpg
#   inflating: train/cityscapes_data/val/397.jpg
#   inflating: train/cityscapes_data/val/398.jpg
#   inflating: train/cityscapes_data/val/399.jpg
#   inflating: train/cityscapes_data/val/4.jpg
#   inflating: train/cityscapes_data/val/40.jpg
#   inflating: train/cityscapes_data/val/400.jpg
#   inflating: train/cityscapes_data/val/401.jpg
#   inflating: train/cityscapes_data/val/402.jpg
#   inflating: train/cityscapes_data/val/403.jpg
#   inflating: train/cityscapes_data/val/404.jpg
#   inflating: train/cityscapes_data/val/405.jpg
#   inflating: train/cityscapes_data/val/406.jpg
#   inflating: train/cityscapes_data/val/407.jpg
#   inflating: train/cityscapes_data/val/408.jpg
#   inflating: train/cityscapes_data/val/409.jpg
#   inflating: train/cityscapes_data/val/41.jpg
#   inflating: train/cityscapes_data/val/410.jpg
#   inflating: train/cityscapes_data/val/411.jpg
#   inflating: train/cityscapes_data/val/412.jpg
#   inflating: train/cityscapes_data/val/413.jpg
#   inflating: train/cityscapes_data/val/414.jpg
#   inflating: train/cityscapes_data/val/415.jpg
#   inflating: train/cityscapes_data/val/416.jpg
#   inflating: train/cityscapes_data/val/417.jpg
#   inflating: train/cityscapes_data/val/418.jpg
#   inflating: train/cityscapes_data/val/419.jpg
#   inflating: train/cityscapes_data/val/42.jpg
#   inflating: train/cityscapes_data/val/420.jpg
#   inflating: train/cityscapes_data/val/421.jpg
#   inflating: train/cityscapes_data/val/422.jpg
#   inflating: train/cityscapes_data/val/423.jpg
#   inflating: train/cityscapes_data/val/424.jpg
#   inflating: train/cityscapes_data/val/425.jpg
#   inflating: train/cityscapes_data/val/426.jpg
#   inflating: train/cityscapes_data/val/427.jpg
#   inflating: train/cityscapes_data/val/428.jpg
#   inflating: train/cityscapes_data/val/429.jpg
#   inflating: train/cityscapes_data/val/43.jpg
#   inflating: train/cityscapes_data/val/430.jpg
#   inflating: train/cityscapes_data/val/431.jpg
#   inflating: train/cityscapes_data/val/432.jpg
#   inflating: train/cityscapes_data/val/433.jpg
#   inflating: train/cityscapes_data/val/434.jpg
#   inflating: train/cityscapes_data/val/435.jpg
#   inflating: train/cityscapes_data/val/436.jpg
#   inflating: train/cityscapes_data/val/437.jpg
#   inflating: train/cityscapes_data/val/438.jpg
#   inflating: train/cityscapes_data/val/439.jpg
#   inflating: train/cityscapes_data/val/44.jpg
#   inflating: train/cityscapes_data/val/440.jpg
#   inflating: train/cityscapes_data/val/441.jpg
#   inflating: train/cityscapes_data/val/442.jpg
#   inflating: train/cityscapes_data/val/443.jpg
#   inflating: train/cityscapes_data/val/444.jpg
#   inflating: train/cityscapes_data/val/445.jpg
#   inflating: train/cityscapes_data/val/446.jpg
#   inflating: train/cityscapes_data/val/447.jpg
#   inflating: train/cityscapes_data/val/448.jpg
#   inflating: train/cityscapes_data/val/449.jpg
#   inflating: train/cityscapes_data/val/45.jpg
#   inflating: train/cityscapes_data/val/450.jpg
#   inflating: train/cityscapes_data/val/451.jpg
#   inflating: train/cityscapes_data/val/452.jpg
#   inflating: train/cityscapes_data/val/453.jpg
#   inflating: train/cityscapes_data/val/454.jpg
#   inflating: train/cityscapes_data/val/455.jpg
#   inflating: train/cityscapes_data/val/456.jpg
#   inflating: train/cityscapes_data/val/457.jpg
#   inflating: train/cityscapes_data/val/458.jpg
#   inflating: train/cityscapes_data/val/459.jpg
#   inflating: train/cityscapes_data/val/46.jpg
#   inflating: train/cityscapes_data/val/460.jpg
#   inflating: train/cityscapes_data/val/461.jpg
#   inflating: train/cityscapes_data/val/462.jpg
#   inflating: train/cityscapes_data/val/463.jpg
#   inflating: train/cityscapes_data/val/464.jpg
#   inflating: train/cityscapes_data/val/465.jpg
#   inflating: train/cityscapes_data/val/466.jpg
#   inflating: train/cityscapes_data/val/467.jpg
#   inflating: train/cityscapes_data/val/468.jpg
#   inflating: train/cityscapes_data/val/469.jpg
#   inflating: train/cityscapes_data/val/47.jpg
#   inflating: train/cityscapes_data/val/470.jpg
#   inflating: train/cityscapes_data/val/471.jpg
#   inflating: train/cityscapes_data/val/472.jpg
#   inflating: train/cityscapes_data/val/473.jpg
#   inflating: train/cityscapes_data/val/474.jpg
#   inflating: train/cityscapes_data/val/475.jpg
#   inflating: train/cityscapes_data/val/476.jpg
#   inflating: train/cityscapes_data/val/477.jpg
#   inflating: train/cityscapes_data/val/478.jpg
#   inflating: train/cityscapes_data/val/479.jpg
#   inflating: train/cityscapes_data/val/48.jpg
#   inflating: train/cityscapes_data/val/480.jpg
#   inflating: train/cityscapes_data/val/481.jpg
#   inflating: train/cityscapes_data/val/482.jpg
#   inflating: train/cityscapes_data/val/483.jpg
#   inflating: train/cityscapes_data/val/484.jpg
#   inflating: train/cityscapes_data/val/485.jpg
#   inflating: train/cityscapes_data/val/486.jpg
#   inflating: train/cityscapes_data/val/487.jpg
#   inflating: train/cityscapes_data/val/488.jpg
#   inflating: train/cityscapes_data/val/489.jpg
#   inflating: train/cityscapes_data/val/49.jpg
#   inflating: train/cityscapes_data/val/490.jpg
#   inflating: train/cityscapes_data/val/491.jpg
#   inflating: train/cityscapes_data/val/492.jpg
#   inflating: train/cityscapes_data/val/493.jpg
#   inflating: train/cityscapes_data/val/494.jpg
#   inflating: train/cityscapes_data/val/495.jpg
#   inflating: train/cityscapes_data/val/496.jpg
#   inflating: train/cityscapes_data/val/497.jpg
#   inflating: train/cityscapes_data/val/498.jpg
#   inflating: train/cityscapes_data/val/499.jpg
#   inflating: train/cityscapes_data/val/5.jpg
#   inflating: train/cityscapes_data/val/50.jpg
#   inflating: train/cityscapes_data/val/500.jpg
#   inflating: train/cityscapes_data/val/51.jpg
#   inflating: train/cityscapes_data/val/52.jpg
#   inflating: train/cityscapes_data/val/53.jpg
#   inflating: train/cityscapes_data/val/54.jpg
#   inflating: train/cityscapes_data/val/55.jpg
#   inflating: train/cityscapes_data/val/56.jpg
#   inflating: train/cityscapes_data/val/57.jpg
#   inflating: train/cityscapes_data/val/58.jpg
#   inflating: train/cityscapes_data/val/59.jpg
#   inflating: train/cityscapes_data/val/6.jpg
#   inflating: train/cityscapes_data/val/60.jpg
#   inflating: train/cityscapes_data/val/61.jpg
#   inflating: train/cityscapes_data/val/62.jpg
#   inflating: train/cityscapes_data/val/63.jpg
#   inflating: train/cityscapes_data/val/64.jpg
#   inflating: train/cityscapes_data/val/65.jpg
#   inflating: train/cityscapes_data/val/66.jpg
#   inflating: train/cityscapes_data/val/67.jpg
#   inflating: train/cityscapes_data/val/68.jpg
#   inflating: train/cityscapes_data/val/69.jpg
#   inflating: train/cityscapes_data/val/7.jpg
#   inflating: train/cityscapes_data/val/70.jpg
#   inflating: train/cityscapes_data/val/71.jpg
#   inflating: train/cityscapes_data/val/72.jpg
#   inflating: train/cityscapes_data/val/73.jpg
#   inflating: train/cityscapes_data/val/74.jpg
#   inflating: train/cityscapes_data/val/75.jpg
#   inflating: train/cityscapes_data/val/76.jpg
#   inflating: train/cityscapes_data/val/77.jpg
#   inflating: train/cityscapes_data/val/78.jpg
#   inflating: train/cityscapes_data/val/79.jpg
#   inflating: train/cityscapes_data/val/8.jpg
#   inflating: train/cityscapes_data/val/80.jpg
#   inflating: train/cityscapes_data/val/81.jpg
#   inflating: train/cityscapes_data/val/82.jpg
#   inflating: train/cityscapes_data/val/83.jpg
#   inflating: train/cityscapes_data/val/84.jpg
#   inflating: train/cityscapes_data/val/85.jpg
#   inflating: train/cityscapes_data/val/86.jpg
#   inflating: train/cityscapes_data/val/87.jpg
#   inflating: train/cityscapes_data/val/88.jpg
#   inflating: train/cityscapes_data/val/89.jpg
#   inflating: train/cityscapes_data/val/9.jpg
#   inflating: train/cityscapes_data/val/90.jpg
#   inflating: train/cityscapes_data/val/91.jpg
#   inflating: train/cityscapes_data/val/92.jpg
#   inflating: train/cityscapes_data/val/93.jpg
#   inflating: train/cityscapes_data/val/94.jpg
#   inflating: train/cityscapes_data/val/95.jpg
#   inflating: train/cityscapes_data/val/96.jpg
#   inflating: train/cityscapes_data/val/97.jpg
#   inflating: train/cityscapes_data/val/98.jpg
#   inflating: train/cityscapes_data/val/99.jpg

# %%
import shutil
shutil.rmtree('/content/train/cityscapes_data/cityscapes_data', ignore_errors=True)

# %%
def loadImages(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image)
    
    slice_index = tf.shape(image)[1]
    slice_index = slice_index//2
    
    input_image = image[:, :slice_index, :]
    target_image = image[:, slice_index:, :]
    
    input_image = tf.cast(input_image, tf.float32)
    target_image = tf.cast(target_image, tf.float32)
    
    return input_image, target_image

def resizeImages(input_image, target_image, height, width):
    input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    target_image = tf.image.resize(target_image, [height, width],
                               method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    
    return input_image, target_image

IMG_HEIGHT, IMG_WIDTH = 256, 256
def random_crop(input_image, target_image):
    stacked_image = tf.stack([input_image, target_image], axis=0)
    cropped_image = tf.image.random_crop(
        stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])
    
    return cropped_image[0], cropped_image[1]

def normalize(input_image, target_image):
    input_image = (input_image / 127.5) - 1
    target_image = (target_image / 127.5) - 1

    return input_image, target_image

def normalize_simple(input_image, target_image):
    input_image = (input_image - np.amin(input_image))/(np.amax(input_image)-np.amin(input_image))

    target_image = (target_image - np.amin(target_image))/(np.amax(target_image)-np.amin(target_image))
    
    return input_image, target_image

def random_jitter(input_image, target_image):
  # resizing to 286 x 286 x 3
    input_image, target_image = resizeImages(input_image, target_image, 286, 286)

    # randomly cropping to 256 x 256 x 3
    input_image, target_image = random_crop(input_image, target_image)
    if tf.random.uniform(()) > 0.5:
    # random mirroring
        input_image = tf.image.flip_left_right(input_image)
        target_image = tf.image.flip_left_right(target_image)

    return input_image, target_image

def collectImages(path):
    input_images, target_images = [], []
    for fname in os.listdir(path):
        input_image, target_image = loadImages(os.path.join(path, fname))
        input_image, target_image = random_jitter(input_image, target_image)
        input_image, target_image = normalize_simple(input_image, target_image)
        input_images.append(input_image)
        target_images.append(target_image)
        #list_of_images.append((real_image, input_image))
        
    return input_images, target_images

# %%
train_path = "/content/train/cityscapes_data/train"
train_input_images, train_target_images = collectImages(train_path)

# %%
test_path = "/content/train/cityscapes_data/val"
test_input_images, test_target_images = collectImages(test_path)

# %%
train_input_images = tf.stack(train_input_images)
train_target_images = tf.stack(train_target_images)

# %%
test_input_images = tf.stack(test_input_images)
test_target_images = tf.stack(test_target_images)

# %%
plt.imshow(test_target_images[105])

# %%
def downsample(filters, kernel_size=3, batch_norm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(filters, kernel_size, padding='same', 
                                    kernel_initializer="glorot_uniform"))
    #model.add(tf.keras.layers.Conv2D(filters, kernel_size, padding='same', 
                                    #kernel_initializer=initializer))    
    model.add(tf.keras.layers.ReLU())
    if batch_norm:
        model.add(tf.keras.layers.BatchNormalization())
        
    return model

## upsampling block
def upsample(filters, kernel_size=3, batch_norm=True, drop_out=True):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(filters, kernel_size, padding='same', 
                                    kernel_initializer='glorot_uniform'))
    model.add(tf.keras.layers.ReLU())
    if batch_norm:
        model.add(tf.keras.layers.BatchNormalization())
    if drop_out:
        model.add(tf.keras.layers.Dropout(0.3))
    model.add(tf.keras.layers.Conv2DTranspose(filters,3, strides = 2, padding='same'))    
    
    return model

def bottom(filters, kernel_size=3, batch_norm=True, drop_out=True):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(filters, kernel_size, padding='same', 
                                    kernel_initializer='glorot_uniform'))
    model.add(tf.keras.layers.ReLU())
    if batch_norm:
        model.add(tf.keras.layers.BatchNormalization())
    if drop_out:
        model.add(tf.keras.layers.Dropout(0.3))
        
    return model

def final_layer(filters_out, filters, kernel_size, batch_norm=True, drop_out=True):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(filters, kernel_size, padding='same',
                                    kernel_initializer='glorot_uniform'))
    model.add(tf.keras.layers.ReLU())
    if batch_norm:
        model.add(tf.keras.layers.BatchNormalization())
    if drop_out:
        model.add(tf.keras.layers.Dropout(0.3))
    
    model.add(tf.keras.layers.Conv2D(filters, kernel_size, padding='same',
                                    kernel_initializer='glorot_uniform'))
    model.add(tf.keras.layers.ReLU())
    if batch_norm:
        model.add(tf.keras.layers.BatchNormalization())
    if drop_out:
        model.add(tf.keras.layers.Dropout(0.3))
    
    model.add(tf.keras.layers.Conv2D(filters_out, kernel_size, padding='same',
                                    kernel_initializer='glorot_uniform'))
    model.add(tf.keras.layers.ReLU())
    if batch_norm:
        model.add(tf.keras.layers.BatchNormalization())

    return model

# %%
class Generator(tf.keras.Model):
    def __init__(self):
        super(Generator, self).__init__()
        self.skip_list = []
        
        self.down1= downsample(64, 3)
        self.m1 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
        
        self.down2 = downsample(128, 3)
        self.m2 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
        
        self.down3 = downsample(256, 3)
        self.m3 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
        
        self.down4 = downsample(512, 3)
        self.m4 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
        
        self.down5 = downsample(512, 3)
        self.m5 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
        
        self.down6 = downsample(512, 3)
        self.m6 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
        
        self.down7 = downsample(512, 3)
        self.m7 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))
        
        self.bottom = bottom(512, 3)
        
        self.u1 = tf.keras.layers.Conv2DTranspose(512,3, strides = 2, padding='same')
        
        self.up1 = upsample(512, 3)
        
        self.up2 = upsample(512, 3)
        
        self.up3 = upsample(512, 3)
        
        self.up4 = upsample(256, 3)
        
        self.up5 = upsample(128, 3)
        
        self.up6 = upsample(64, 3)
        
        self.final_layer = final_layer(3, 64, 3)
        
    def call_model(self):
        ## defining the input shape
        inputs = tf.keras.layers.Input(shape=[256,256,3])
        
        x = inputs
        print('input', x.shape)
        
        x = self.down1(x)
        c1 = x
        x = self.m1(x)
        print('c1', x.shape)
        
        x = self.down2(x)
        c2 = x
        x = self.m2(x)
        print('c2', x.shape)
        
        x = self.down3(x)
        c3 = x
        x = self.m3(x)
        print('c3', x.shape)
        
        x = self.down4(x)
        c4 = x
        x = self.m4(x)
        print('c4', x.shape)
        
        x = self.down5(x)
        c5 = x
        x = self.m5(x)
        print('c5', x.shape)
        
        x = self.down6(x)
        c6 = x
        x = self.m6(x)
        print('c6', x.shape)
        
        x = self.down7(x)
        c7 = x
        x = self.m7(x)
        print('c7', x.shape)
        
        x = self.bottom(x)
        print('bottom', x.shape)
        
        x = self.u1(x)
        print('u1', x.shape)
        
        x = self.up1(tf.keras.layers.concatenate([x, c7], axis=3))
        print('up1', x.shape)
        
        x = self.up2(tf.keras.layers.concatenate([x, c6], axis=3))
        print('up2', x.shape)
        
        x = self.up3(tf.keras.layers.concatenate([x, c5], axis=3))
        print('up3', x.shape)
        
        x = self.up4(tf.keras.layers.concatenate([x, c4], axis=3))
        print('up4', x.shape)
        
        x = self.up5(tf.keras.layers.concatenate([x, c3], axis=3))
        print('up5', x.shape)
        
        x = self.up6(tf.keras.layers.concatenate([x, c2], axis=3))
        print('up6', x.shape)
        
        x = self.final_layer(tf.keras.layers.concatenate([x, c1], axis=3))
        print('up7', x.shape)
        
        return tf.keras.Model(inputs=inputs, outputs=x)

# %%
path = "/content/train/cityscapes_data/train"
inp, rel = loadImages(path+'/109.jpg')
inp, rel = resizeImages(inp, rel, 256, 256)
plt.figure(0)
plt.imshow(inp/255)

# %%
generator = Generator().call_model()
print(type(generator))
gen = generator(inp[tf.newaxis, ...], training=True)
plt.imshow(gen[0])
# Out:
# input (None, 256, 256, 3)
# c1 (None, 128, 128, 64)
# c2 (None, 64, 64, 128)
# c3 (None, 32, 32, 256)
# c4 (None, 16, 16, 512)
# c5 (None, 8, 8, 512)
# c6 (None, 4, 4, 512)
# c7 (None, 2, 2, 512)
# bottom (None, 2, 2, 512)
# u1 (None, 4, 4, 512)
# up1 (None, 8, 8, 512)
# up2 (None, 16, 16, 512)
# up3 (None, 32, 32, 512)
# up4 (None, 64, 64, 256)
# up5 (None, 128, 128, 128)
# up6 (None, 256, 256, 64)
# up7 (None, 256, 256, 3)
# <class 'tensorflow.python.keras.engine.training.Model'>
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
initializer = tf.random_normal_initializer(0., 0.02)

class Discriminator(tf.keras.Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        #initializer = tf.random_normal_initializer(0., 0.02)
        self.down1 = downsample(64, 4)
        self.m1 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))

        self.down2 = downsample(128, 4)
        self.m2 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))

        self.down3 = downsample(256, 4)
        self.m3 = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))

        self.zero_padding1 = tf.keras.layers.ZeroPadding2D()
        self.c1 = tf.keras.layers.Conv2D(512, 4, strides=1, 
                                        kernel_initializer='glorot_uniform', use_bias=False)

        self.batchnorm = tf.keras.layers.BatchNormalization()
        self.leaky_relu = tf.keras.layers.LeakyReLU()

        self.zero_padding2 = tf.keras.layers.ZeroPadding2D()
        self.c2 = tf.keras.layers.Conv2D(1, 4, strides=1,
                                        kernel_initializer='glorot_uniform')
            
    def call_model(self):
        inp = tf.keras.layers.Input(shape=[256, 256, 3], name='input_image')
        tar = tf.keras.layers.Input(shape=[256, 256, 3], name='target_image')

        x = tf.keras.layers.concatenate([inp, tar], axis=3)
        print(x.shape)
        y = x

        x = self.down1(x)
        x = self.m1(x)
        print(x.shape)

        x = self.down2(x)
        x = self.m2(x)
        print(x.shape)

        x = self.down3(x)
        x = self.m3(x)
        print(x.shape)
        
        x = self.zero_padding1(x)
        print(x.shape)
        x = self.c1(x)
        print(x.shape)
        x = self.batchnorm(x)
        print(x.shape)
        x = self.leaky_relu(x)
        print(x.shape)
        x = self.zero_padding2(x)
        print(x.shape)
        x = self.c2(x)
        print(x.shape)

        return tf.keras.Model(inputs=[inp, tar], outputs=x)

# %%
discriminator = Discriminator().call_model()
#print(type(generator))
disc = discriminator([rel[tf.newaxis, ...], gen], training=True)
plt.imshow(disc[0,...,-1], vmin=-20, vmax=20, cmap='RdBu_r')
# Out:
# (None, 256, 256, 6)
# (None, 128, 128, 64)
# (None, 64, 64, 128)
# (None, 32, 32, 256)
# (None, 34, 34, 256)
# (None, 31, 31, 512)
# (None, 31, 31, 512)
# (None, 31, 31, 512)
# (None, 33, 33, 512)
# (None, 30, 30, 1)

# %%
def generate_images(model, inp, tar):
    prediction = model(inp, training=True)
    plt.figure(figsize=(15,15))

    display_list = [inp[0], tar[0], prediction[0]]
    title = ['Input Image', 'Ground Truth', 'Predicted Image']

    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i])
        plt.axis('off')
    plt.show()

# %%
x = inp[tf.newaxis, ...]/255
c = rel[tf.newaxis, ...]/255
generate_images(generator, x, c)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
def generator_loss(disc_gen_out, gen_out, target_image):
    gan_loss = loss_object(tf.ones_like(disc_gen_out), disc_gen_out)
    
    mae_loss = tf.reduce_mean(tf.abs(target_image - gen_out))
    
    Lambda = 100 
    
    total_gen_loss = mae_loss*Lambda + gan_loss
    
    return total_gen_loss, mae_loss, gan_loss

def discriminator_loss(disc_gen_in, disc_tar_in):
    disc_real_loss = loss_object(tf.ones_like(disc_tar_in), disc_tar_in)
    disc_gen_loss = loss_object(tf.zeros_like(disc_gen_in), disc_gen_in)
    
    total_disc_loss = disc_real_loss + disc_gen_loss
    
    return total_disc_loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
@tf.function
def train_step(input_image, target):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        
        gen_output = generator(input_image, training=True)

        disc_real_output = discriminator([input_image, target], training=True)
        disc_generated_output = discriminator([input_image, gen_output], training=True)

        gen_total_loss, gen_gan_loss, gen_l1_loss = generator_loss(disc_generated_output, gen_output, target)
        disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

    generator_gradients = gen_tape.gradient(gen_total_loss,
                                      generator.trainable_variables)
    discriminator_gradients = disc_tape.gradient(disc_loss,
                                            discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(generator_gradients,
                                      generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                          discriminator.trainable_variables))
    
    return gen_total_loss, disc_loss

# %%
import random
batch_size = 15
num_batches = len(train_input_images)//batch_size
epochs = 10

print("Start of training")
print()
for epoch in range(epochs):
    genLosses = 0
    discLosses = 0
    print('start of epoch ',  epoch+1)
    for batch in range(num_batches):
        inp = train_input_images[batch*batch_size: (batch+1)*batch_size]
        tar = train_target_images[batch*batch_size: (batch+1)*batch_size]
        genLoss, discLoss = train_step(inp, tar)
        genLosses = genLosses + genLoss
        discLosses = discLosses + discLoss
        print('.', end='')
    print()
    print("Losses after epoch", epoch+1, ":")
    print("Gen Loss:", genLosses/num_batches)
    print("Disc Loss:", discLosses/num_batches)
    c = random.randint(0, test_target_images.shape[0])
    generate_images(generator, test_input_images[c:c+1], test_target_images[c:c+1])
    print('end of epoch ',  epoch+1)
    print()
print("end of training")
# Out:
# Start of training
#
# start of epoch  1
# ........
